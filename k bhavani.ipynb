# %%
print("hello,world:")
# Out:
# hello,world:

# %%
print(5)
# Out:
# 5

# %%
print(4+5)
# Out:
# 9

# %%
print(3%6)
# Out:
# 3

# %%
print(7*9)
# Out:
# 63

# %%
print('hello world')
# Out:
# hello world

# %%
print('hello KGRCT')
# Out:
# hello KGRCT

# %%
print('welcome to  python workshop')
# Out:
# welcome to  python workshop

# %%
x="KGRCET"
print(x)
# Out:
# KGRCET

# %% [markdown]
# program

# %%
age=19
print("I am"+str(age)+"years old")
# Out:
# I am19years old

# %%
x=5
y="KGRCET"
print(x)
print(y)
# Out:
# 5
# KGRCET

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x="python"
y="is"
z="awessom"
print(x+Y+z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f6f394cac2be> in <cell line: 0>()
#       2 y="is"
#       3 z="awessom"
# ----> 4 print(x+Y+z)
#
# NameError: name 'Y' is not defined

# %%
x,y=2,3
x
# Out:
# 2

# %% [markdown]
# swapping numbers

# %%
a=10
b=20

# %%
a,b=b,a

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-645194eee454> in <cell line: 0>()
# ----> 1 x,y,z,="orange","banana",
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x=str(3)
y=int(3)
z=float(3)

# %% [markdown]
# numeric data type

# %%
a=5
print(type(a))
b=5.0
print(type(b))
c=2+4j
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
s='welcom to python workshop'
print(s)
#check data type
print(type(s))
#acces string withbindex
print(s[1])
print(s[2])
print(s[-1])
# Out:
# welcom to python workshop
# <class 'str'>
# e
# l
# p

# %%
string_one="I'm reading"
string_two="a new great book"
string_three=string_one+string_two
print (string_three)
# Out:
# I'm readinga new great book

# %%
'alice' *5
print("bhavani "*5)
# Out:
# bhavani bhavani bhavani bhavani bhavani

# %%
b=["kgr",1,2,3]

# %%
b[2:4]
# Out:
# [2, 3]

# %%
alpha_list=[34,23,67,100,88,2]
alpha_list.sort()
alpha_list
[2,23,34,67,88,100]
# Out:
# [2, 23, 34, 67, 88, 100]

# %% [markdown]
# slice a list

# %%
beta_list=["apple","banana","orange"]
beta_list.append("grapes")
print(beta_list)
# Out:
# ['apple', 'banana', 'orange', 'grapes']

# %%
beta_list=["apple","banana","orange"]
beta_list.insert(2,"grape")
print(beta_list)
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
beta_list=["apple","banana","orange"]
beta_list.remove("banana")
print(beta_list)
# Out:
# ['apple', 'orange']

# %%
beta_list=["apple","banana","orange"]
beta_list.insert(2,"grape")
print(beta_list)
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
beta_list=["apple","banana","orange"]
beta_list.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c5a2a7d0fabc> in <cell line: 0>()
#       1 beta_list=["apple","banana","orange"]
# ----> 2 beta_list.remove()
#
# TypeError: list.remove() takes exactly one argument (0 given)
